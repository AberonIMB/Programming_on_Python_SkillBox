# %% [markdown]
# # Numpy
# ### Если задания покажутся сложными, рекомендую пройти краткий курс по основам numpy [ссылка1](https://stepik.org/lesson/241329/step/1?unit=213910), [ссылка2](https://stepik.org/lesson/16462/step/1?unit=4283)

# %%
import numpy as np
import random
import scipy.stats as sps
import cv2

# %% [markdown]
# ### Задание 1
# В первой задаче вам предлагается перемножить две квадратные матрицы двумя способами -- без использования пакета ***numpy*** и с ним.

# %%
# Для генерации матриц используем фукнцию random -- она используется для генерации случайных объектов
# функция sample создает случайную выборку. В качестве аргумента ей передается кортеж (i,j),
# здесь i -- число строк, j -- число столбцов.
a = np.random.sample((100, 100))
b = np.random.sample((100, 100))
# выведите размерность (ранг) каждой матрицы с помощью функции ndim.
# Используйте функцию shape, что она вывела?
# ========
print("ранг a =",a.ndim, "\nранг b =", b.ndim)
print("размер матрицы a =",a.shape,"\nразмер матрицы b =",b.shape)
# ========
print(a)
print(b)
# Out:
# ранг a = 2
# ранг b = 2
# размер матрицы a = (100, 100)
# размер матрицы b = (100, 100)
# [[0.49799463 0.09221673 0.12012229 ... 0.9857974  0.60478586 0.27264523]
#  [0.71503676 0.51440121 0.45824151 ... 0.55851078 0.98940144 0.0306147 ]
#  [0.1722417  0.22777135 0.62945501 ... 0.09020327 0.79683097 0.32049318]
#  ...
#  [0.6005433  0.44173842 0.70795172 ... 0.34185273 0.12967368 0.38667553]
#  [0.41309735 0.2977195  0.2139318  ... 0.82333605 0.20577767 0.16309415]
#  [0.61748721 0.81741988 0.6846291  ... 0.26741392 0.81544501 0.28174852]]
# [[0.39646322 0.80429183 0.37128787 ... 0.1396542  0.78039839 0.81515304]
#  [0.29616746 0.22327388 0.11195768 ... 0.1290761  0.36237747 0.8766168 ]
#  [0.17671148 0.9692845  0.68178288 ... 0.33160645 0.88305488 0.10250286]
#  ...
#  [0.70983796 0.63687614 0.01729475 ... 0.41945533 0.0170853  0.53464465]
#  [0.35385423 0.31746284 0.69934549 ... 0.9933044  0.23947503 0.9828641 ]
#  [0.25412765 0.23787226 0.25748183 ... 0.18467509 0.60503358 0.18842029]]

# %% [markdown]
# Без использования numpy

# %%
def mult(a, b):
    result = [[0 for _ in range(len(b[0]))] for _ in range(len(a))]
    for i in range(len(a)):
        for j in range(len(b[0])):
            for k in range(len(b)):
                result[i][j] += a[i][k] * b[k][j]
    return result

# %% [markdown]
# C использованием numpy

# %%
def np_mult(a, b):
    result = np.dot(a, b)
    return result

# %%
# %%time
# засечем время работы функции без NumPy
M1 = mult(a, b)
# Out:
# CPU times: user 735 ms, sys: 2.12 ms, total: 737 ms
# Wall time: 738 ms

# %%
# %%time
# засечем время работы функции с NumPy
M2 = np_mult(a, b)
# Out:
# CPU times: user 2.01 ms, sys: 177 µs, total: 2.19 ms
# Wall time: 6.26 ms

# %%
# проверим корректность
np.abs(np.array(M1) - M2).sum()
# Out:
# 1.5274892462002754e-11

# %% [markdown]
# ### Задание 2

# %% [markdown]
# Вам подаются на вход два вектора `a` и `b` в трехмерном пространстве. Заполните их случайными числами. Реализуйте их скалярное произведение с помощью  `NumPy` и без. Засеките время работы, как это показано в заданиях выше.

# %%
a = np.random.sample((1, 3))
a = list(a)[0]
b = np.random.sample((1, 3))
b = list(b)[0]
print(a, b)
# Out:
# [0.70259326 0.6061658  0.55664323] [0.03600484 0.89721716 0.45874709]

# %%
def scalar_product(a,b):
    s = sum(x * y for x,y in zip(a, b))
    return s

# %%
def np_scalar_product(a,b):
    s = np.dot(a, b)
    return s

# %%
# %time product_1 = scalar_product(a,b)
# %time product_2 = np_scalar_product(a,b)
# проверим корректность:
np.abs(product_1 - product_2).sum()
# Out:
# 0.824517584851638
# CPU times: user 1.95 ms, sys: 0 ns, total: 1.95 ms
# Wall time: 1.84 ms
# 0.824517584851638
# CPU times: user 587 µs, sys: 0 ns, total: 587 µs
# Wall time: 914 µs
# 0.0

# %% [markdown]
# Почему методы ***numpy*** оказываются эффективнее? Что вы можете сказать о скорости вычислений в NumPy?

# %% [markdown]
# **Ответ:** NumPy обеспечивает высокую производительность благодаря реализации на C/C++, векторизации операций и оптимизированным алгоритмам

# %% [markdown]
# ------------------

# %% [markdown]
# ### Задание 3
# Напишите функцию, которая находим сумму четных диагональныех элементов квадратной матрицы. Если таких элементов нет, то вывести `0`.

# %%
# функция, решающая задачу с помощью NumPy
def np_diag_2k(a):
    size = a.shape[0]
    diagonal1 = np.diagonal(a)
    diagonal2 = np.diagonal(np.fliplr(a))
    result = sum(diagonal1[diagonal1 % 2 == 0]) + sum(diagonal2[diagonal2 % 2 == 0])

    if size % 2 == 1:
        center_element = a[size // 2, size // 2]
        if center_element % 2 == 0:
            result -= center_element
    return result

# %%
# зададим некоторую квадратную матрицу
a = np.random.randint(1, 10, size=(5, 5))
a
# Out:
# array([[5, 7, 9, 3, 4],
#        [9, 3, 3, 8, 4],
#        [5, 8, 6, 8, 6],
#        [9, 6, 5, 5, 9],
#        [9, 8, 1, 9, 3]])

# %%
# %%time
# засечем время работы функции с NumPy
np_diag_2k(a)
# Out:
# CPU times: user 237 µs, sys: 0 ns, total: 237 µs
# Wall time: 245 µs
# 24

# %% [markdown]
# ### Задание 4
# На вход дан двумерный массив $X$. Напишите функцию, которая для каждой строчки $x = (x_1, x_2, \ldots, x_n)$ массива $X$  строит строчку $s = (s_1, s_2, \ldots, s_n)$, где $s_k=\frac{x_1+...+x_k}{k}$, а затем выдаёт массив из построенных строчек. Используйте библиотеку numpy (вам поможет функция cumsum). Выходом функции должен быть двумерный массив той же формы, что и $X$.

# %%
# функция, решающая задачу с помощью NumPy
def np_sec_av(A):
    cumsum = np.cumsum(a, axis=1)
    row_indexes = np.arange(1, a.shape[1] + 1)
    result = cumsum / row_indexes
    return result

# %%
# зададим некоторую последовательность и проверим ее на ваших функциях.
# функция должна работать ~ в 50 раз быстрее, чем без Numpy
A = sps.uniform.rvs(size=10**3)
print(A)

# %time S2 = np_sec_av(A)
# Out:
#  5.09497796e-01 6.13002873e-01 8.55058366e-01 6.42489751e-01
#  1.26720545e-01 5.00938926e-01 8.81471547e-01 1.36809858e-01
#  7.43463756e-01 8.16553722e-01 8.50032546e-01 4.84817612e-01
#  1.07719779e-01 8.54196717e-01 5.11267677e-01 9.73072572e-01
#  1.36957923e-01 3.40218376e-01 8.29825212e-01 7.80350745e-01
#  7.20475330e-01 8.58518620e-02 6.09106214e-01 3.11203910e-01
#  8.97585726e-02 2.12353860e-01 1.00701237e-01 1.32132643e-01
#  6.42788869e-01 9.64542019e-01 2.60104242e-01 7.20729542e-01
#  6.52013557e-01 3.80914098e-01 5.88935785e-01 2.98343180e-01
#  5.30761877e-01 5.79028186e-01 7.39254130e-01 7.84114964e-01
#  6.54104109e-01 5.35900795e-01 8.81562534e-02 2.20620831e-01
#  6.73345916e-01 1.41908218e-01 8.37976271e-01 2.81162375e-01]
# CPU times: user 97 µs, sys: 0 ns, total: 97 µs
# Wall time: 102 µs

# %% [markdown]
# ### Задание 5
# Написать функцию для кодирование массива (Run-length encoding). Все подряд повторения элементов функция сжимает в один элемент и считает количество повторений. Функция возвращает кортеж из двух векторов одинаковой длины. Первый содержит элементы, а второй — сколько раз их нужно повторить.
#
# Пример: encode(np.array([1, 2, 2, 3, 3, 1, 1, 5, 5, 2, 3, 3])) = (np.array[1, 2, 3, 1, 5, 2, 3]), np.array[1, 2, 2, 2, 2, 1, 2])

# %%
# функция, решающая задачу с помощью NumPy
def np_encode(a):
    unique_elements_indexes = np.where(np.diff(a) != 0)[0] + 1
    unique_elements_arrays = np.split(a, unique_elements_indexes)

    unique_elements = np.array([subarray[0] for subarray in unique_elements_arrays])
    counts = np.array([len(subarray) for subarray in unique_elements_arrays])
    return unique_elements, counts

# %%
from itertools import groupby
X = np.array([1, 2, 2, 3, 3, 1, 1, 5, 5, 2, 3, 3])
# %time x, num = np_encode(X)
# Out:
# CPU times: user 174 µs, sys: 24 µs, total: 198 µs
# Wall time: 204 µs

# %% [markdown]
# ### Задание 6
#
# Пусть задан некоторый одномерный массив $X$. Надо построить новый массив, где все элементы с нечетными индексами требуется заменить на число $a$ (если оно не указано, то на 1). Все элементы с четными индексами нужно возвести в куб. Затем записать элементы в обратном порядке относительно их позиций. Массив $X$ при этом должен остаться *без изменений*. В конце требуется слить массив X с преобразованным X и вывести в обратном порядке.
#
# Пример:
# X = [100, 200, 300, 400, 500] -> [100, a, 300, a, 500] -> [500^3, a, 300^3, a, 100^3] -> склеиваем -> [100, 200, 300, 400, 500, 500^3, a, 300^3, a, 100^3]

# %%
# функция, решающая задачу с помощью NumPy
from copy import copy

def np_transformation(X, a=1):
    """
    param X: array
    """

    arrays_copy = X.copy()
    arrays_copy[1::2] = a
    arrays_copy[0::2] **= 3
    new_array = arrays_copy[::-1]
    result = np.concatenate([X, new_array])
    return result

# %%
X = np.array([i for i in range(1, 10, 2)])
# функция должна работать ~ в 20 раз быстрее, чем без Numpy
# %time S2 = np_transformation(X, 5)
# Out:
# CPU times: user 798 µs, sys: 0 ns, total: 798 µs
# Wall time: 806 µs
